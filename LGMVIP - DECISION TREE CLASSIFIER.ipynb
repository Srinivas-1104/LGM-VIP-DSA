# %% [markdown]
# # Let's Grow More Virtual Internship Program:
#
# __Task Level:    Basic <br>
#   Task Number:   01  <br>
#   Task Name:     Iris Flower Classification__

# %% [markdown]
# ## Basic Idea
#
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data.
# Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.

# %% [markdown]
# ## History of Iris Dataset:
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.

# %% [markdown]
# # Content of the Dataset:
# 1.  The Identification Number
# 2.  The Sepal Length in CM
# 3.  The Sepal Width in CM
# 4.  The Petal Length in CM
# 5.  The Petal Width in CM
# 6.  The Species Name

# %% [markdown]
# ## Dataset Description:
#
# This is perhaps the best known database to be found in the pattern recognition literature. Fisher's paper is a classic in the field and is referenced frequently to this day. (See Duda & Hart, for example.) The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Predicted attribute: class of iris plant.
# This is an exceedingly simple domain.

# %% [markdown]
# # Data Collection:
#
# The data is directly obtained from the sklearn library.
# The data is relatively small and the size is of no consequence

# %%
#  IMPORTS

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#   import the dataset from the Seaborn Library

iris = pd.DataFrame(sns.load_dataset('iris'))

# %% [markdown]
# # Exploratory Data Analysis:
#
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.

# %%
# The Basic Information

iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# The Basic Statistical Ideas for each feature

iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# The Dimensions of the Given Dataset

iris.shape
# Out:
# (150, 5)

# %%
# The Columns (or) Features of the Given Dataset 

iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Is there any null values?

iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# The Correleation Matrix

iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# The Group of Data Available:

iris.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ###  PAIR PLOT
#
# The Pair Plot show the multiple level of relationships with the other attributes and how the graph deviates because of the dependacies.

# %%
# The Pair Plot Comparing everything

sns.pairplot(iris, hue='species')

# %% [markdown]
# ### SCATTER PLOT:
#
# The Species of Setosa is clearly distinguishable as inferred from the scatterplots.  Both the petal and the sepal lengths are smaller compared to others.
#
# The Species of Versicolor is the present in the middle ground.
#
# The Species of Virginica is present in the farthest hollow proving to be longer in both aspects of sepal and petal length.

# %%
# Scatter Plot for the Sepals:

sns.scatterplot(iris['sepal_length'], iris['sepal_width'], hue=iris['species'])

# %%
# Scatter Plot for the Petals:

sns.scatterplot(iris['petal_length'], iris['petal_width'], hue=iris['species'])

# %% [markdown]
# ### HISTOGRAM AND DISTPLOT:
#
# This shows the overlapping tendencies present in the different species of iris flower.

# %%
plot = sns.FacetGrid(iris, hue="species")
plot.map(sns.distplot, "sepal_length").add_legend()

plot = sns.FacetGrid(iris, hue="species")
plot.map(sns.distplot, "sepal_width").add_legend()

plot = sns.FacetGrid(iris, hue="species")
plot.map(sns.distplot, "petal_length").add_legend()

plot = sns.FacetGrid(iris, hue="species")
plot.map(sns.distplot, "petal_width").add_legend()

# %% [markdown]
# ### CORRELEATION AND HEATMAPS:
#
#
# The pairwise correlation of all columns in the dataframe is found and graphically displayed.
#
# The heatmap is a data visualization technique that is used to analyze the dataset as colors in two dimensions. Basically, it shows a correlation between all numerical variables in the dataset.
#
# Petal width and petal length have high correlations.
# Petal length and sepal width have good correlations.
# Petal Width and Sepal length have good correlations.

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot=True, cmap='PuBu')

# %% [markdown]
# ### BOX PLOTS:
#
# It is used to see how the categorical values are distributed.
# It is also used to see how the outliers are situated.

# %%
sns.boxplot(x='species', y='sepal_length', data=iris)

# %%
sns.boxplot(x='species', y='sepal_width', data=iris)

# %%
sns.boxplot(x='species', y='petal_length', data=iris)

# %%
sns.boxplot(x='species', y='petal_width', data=iris)

# %% [markdown]
# ## Choosing the Model:
#
# There are 'n' number of classifier algorithms available for us to explore.
# I chose the __Decision Tree Classifer__.
#
# A decision tree is a flowchart-like tree structure where an internal node represents feature(or attribute), the branch represents a decision rule, and each leaf node represents the outcome.
#
# The topmost node in a decision tree is known as the root node. It learns to partition on the basis of the attribute value.
#
# It partitions the tree in recursively manner call recursive partitioning. This flowchart-like structure helps you in decision making.
#
# It's visualization like a flowchart diagram which easily mimics the human level thinking. That is why decision trees are easy to understand and interpret.

# %%
# Encoding the Categorical Dependent Variables:

from sklearn.preprocessing import LabelEncoder

features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = iris.drop(['species'], 1)
Y = iris['species']


le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
#  Data Splitting:

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 1)

# %%
#  Importing the Decision Tree Classifier

from sklearn import tree

clf = tree.DecisionTreeClassifier(random_state = 1234)

clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=1234)

# %%
#  Model Evaluation:

prediction = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

print ("CONFUSION MATRIX \n")
print(confusion_matrix(Y_test, prediction))

print ("CLASSIFICATION REPORT \n")
print(classification_report(Y_test, prediction))

print ("ACCURACY SCORE \n")
print (accuracy_score(Y_test, prediction))
# Out:
# CONFUSION MATRIX
#
# [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# ACCURACY SCORE
#
# 0.9555555555555556

# %%
# Textual Representation'

text = tree.export_text(clf)
print (text)
# Out:
# |--- feature_2 <= 2.60
# |   |--- class: 0
# |--- feature_2 >  2.60
# |   |--- feature_3 <= 1.65
# |   |   |--- feature_2 <= 5.00
# |   |   |   |--- class: 1
# |   |   |--- feature_2 >  5.00
# |   |   |   |--- feature_0 <= 6.05
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  6.05
# |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.65
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %%
#  Decision Tree  --  plot_tree

from sklearn import datasets
iris = datasets.load_iris()

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %% [markdown]
# # THANKS
